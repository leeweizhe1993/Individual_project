% %%
t = linspace(1e-3, 100e-3, 10);
xn = sin(100 * 2 * pi *t);
N = length(xn);
t, xn, N
% Out:
% t =
%
%     0.0010    0.0120    0.0230    0.0340    0.0450    0.0560    0.0670    0.0780    0.0890    0.1000
%
%
% xn =
%
%     0.5878    0.9511    0.9511    0.5878   -0.0000   -0.5878   -0.9511   -0.9511   -0.5878    0.0000
%
%
% N =
%
%     10

% %%
WNnk = dftmtx(N);
Xk = xn * WNnk
subplot(1, 2, 1);stem(1 : N, xn);
subplot(1, 2, 2);stem(1 : N, abs(Xk));
% Out:
% Xk =
%
%   Columns 1 through 7
%
%    0.0000 + 0.0000i   2.9389 - 4.0451i  -0.0000 + 0.0000i  -0.0000 - 0.0000i   0.0000 + 0.0000i  -0.0000 + 0.0000i   0.0000 - 0.0000i
%
%   Columns 8 through 10
%
%   -0.0000 + 0.0000i  -0.0000 - 0.0000i   2.9389 + 4.0451i
